# %%
import os
import pandas as pd
import numpy as np
def filePathsGen(rootPath):
    """此函數將rootPath資料夾目錄中的所有圖片路徑資訊儲存至一個清單內。"""
    paths = []
    # dirs = []
    for dirPath, dirNames, fileNames in os.walk(rootPath):
        for fileName in fileNames:
            # print(fileName)
            # category = dirPath.split("\\")[-1]  # (Windows)
            fullPath = os.path.join(dirPath, fileName)
            paths.append((fileName, fullPath))
    return paths

# %%
train_paths = filePathsGen("..\\data\\versions\\1\\train_data\\train-old")  # 載入圖片路徑 (Windows)
test_paths = filePathsGen("..\\data\\versions\\1\\test_data\\test_data")  # 載入圖片路徑 (Windows)
df_train_image = pd.DataFrame(train_paths, columns=["image","path"]) # 圖片路徑存成Pandas資料表
df_test_image = pd.DataFrame(test_paths, columns=["image","path"]) # 圖片路徑存成Pandas資料表
df_train_info = pd.read_json("..\\data\\versions\\1\\train.json")
df_test_info = pd.read_json("..\\data\\versions\\1\\test.json")
df_train = pd.merge(df_train_image, df_train_info, left_on='image', right_on='file_name', how='inner').drop(columns=['file_name'])
df_test = pd.merge(df_test_image, df_test_info, left_on='image', right_on='file_name', how='inner').drop(columns=['file_name'])

# %%
# 檢查 boxes 中是否有相同的值並打印 index 和病灶名
for index in range(len(df_train)):  # 假設 df_train 中有多行
    syms = df_train.loc[index]["syms"]  # 獲取 syms 列
    boxes = df_train.loc[index]["boxes"]  # 獲取 boxes 列

    # 找到重複的 boxes
    unique_boxes = []
    duplicate_found = False
    for i, box in enumerate(boxes):
        if box in unique_boxes:
            # 找到重複的病灶名
            duplicate_index = unique_boxes.index(box)
            print(f"Duplicate box found at index {index}: {box}")
            print(f"Corresponding lesions: {syms[duplicate_index]} and {syms[i]}")
            duplicate_found = True
        else:
            unique_boxes.append(box)
    
    # if not duplicate_found:
    #     print(f"No duplicates at index {index}")

# 創建 syms 與 boxes 的映射字典
result_dict_list = []  # 用於存放每個樣本的字典

for index in range(len(df_train)):  # 假設 df_train 中有多行
    syms = df_train.loc[index]["syms"]  # 獲取 syms 列
    boxes = df_train.loc[index]["boxes"]  # 獲取 boxes 列

    # 確保 syms 和 boxes 的長度一致
    if len(syms) != len(boxes):
        print(f"Warning: Mismatch in syms and boxes length at index {index}")
        continue

    # 創建當前樣本的字典
    sample_dict = {syms[j]: boxes[j] for j in range(len(syms))}
    result_dict_list.append(sample_dict)
# Out:
# Duplicate box found at index 85: [243, 662, 407, 886]
# Corresponding lesions: Fibrosis and Consolidation
# Duplicate box found at index 115: [621, 267, 741, 401]
# Corresponding lesions: Fibrosis and Fracture
# Duplicate box found at index 131: [620, 362, 798, 532]
# Corresponding lesions: Mass and Nodule
# Duplicate box found at index 205: [160, 650, 469, 912]
# Corresponding lesions: Fibrosis and Effusion
# Duplicate box found at index 719: [128, 378, 390, 685]
# Corresponding lesions: Atelectasis and Effusion
# Duplicate box found at index 1647: [108, 645, 175, 727]
# Corresponding lesions: Calcification and Nodule
# Duplicate box found at index 1746: [689, 420, 863, 552]
# Corresponding lesions: Fracture and Fracture
# Duplicate box found at index 1929: [319, 167, 370, 291]
# Corresponding lesions: Fibrosis and Fracture
# Duplicate box found at index 2185: [268, 106, 479, 320]
# Corresponding lesions: Fibrosis and Fracture
# Duplicate box found at index 2185: [601, 121, 757, 319]
# Corresponding lesions: Fracture and Fracture
# Duplicate box found at index 2259: [715, 328, 834, 473]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2259: [595, 360, 912, 763]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2260: [597, 244, 920, 671]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2260: [159, 117, 477, 605]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2266: [620, 559, 856, 856]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2268: [115, 51, 524, 862]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2284: [131, 121, 430, 595]
# Corresponding lesions: Fibrosis and Emphysema
# Duplicate box found at index 2285: [182, 146, 494, 648]
# Corresponding lesions: Fibrosis and Emphysema
# Duplicate box found at index 2285: [562, 143, 884, 670]
# Corresponding lesions: Emphysema and Emphysema
# Duplicate box found at index 2286: [190, 179, 470, 697]
# Corresponding lesions: Fibrosis and Emphysema
# Duplicate box found at index 2286: [566, 172, 833, 671]
# Corresponding lesions: Emphysema and Emphysema
# Duplicate box found at index 2290: [159, 430, 391, 759]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2290: [540, 242, 710, 693]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2292: [115, 163, 409, 753]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2292: [540, 171, 826, 830]
# Corresponding lesions: Consolidation and Consolidation
# Duplicate box found at index 2293: [185, 200, 451, 812]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2293: [559, 178, 829, 867]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2294: [601, 318, 863, 799]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2296: [538, 494, 878, 775]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2296: [141, 263, 419, 770]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2298: [526, 275, 831, 745]
# Corresponding lesions: Fibrosis and Consolidation
# Duplicate box found at index 2298: [99, 262, 404, 724]
# Corresponding lesions: Consolidation and Consolidation
# Duplicate box found at index 2303: [569, 149, 836, 620]
# Corresponding lesions: Fibrosis and Consolidation
# Duplicate box found at index 2303: [225, 120, 477, 665]
# Corresponding lesions: Consolidation and Consolidation
# Duplicate box found at index 2304: [581, 178, 833, 654]
# Corresponding lesions: Fibrosis and Consolidation
# Duplicate box found at index 2304: [182, 205, 434, 716]
# Corresponding lesions: Consolidation and Consolidation
# Duplicate box found at index 2307: [593, 189, 847, 523]
# Corresponding lesions: Fibrosis and Consolidation
# Duplicate box found at index 2307: [232, 171, 477, 630]
# Corresponding lesions: Consolidation and Consolidation
# Duplicate box found at index 2311: [555, 242, 818, 835]
# Corresponding lesions: Fibrosis and Consolidation
# Duplicate box found at index 2311: [555, 242, 818, 835]
# Corresponding lesions: Fibrosis and Effusion
# Duplicate box found at index 2311: [148, 246, 424, 833]
# Corresponding lesions: Consolidation and Consolidation
# Duplicate box found at index 2311: [148, 246, 424, 833]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2314: [611, 502, 926, 735]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2315: [125, 313, 180, 391]
# Corresponding lesions: Effusion and Fracture
# Duplicate box found at index 2315: [634, 258, 899, 704]
# Corresponding lesions: Fracture and Consolidation
# Duplicate box found at index 2316: [585, 181, 957, 783]
# Corresponding lesions: Fibrosis and Consolidation
# Duplicate box found at index 2316: [585, 181, 957, 783]
# Corresponding lesions: Fibrosis and Effusion
# Duplicate box found at index 2320: [595, 204, 846, 438]
# Corresponding lesions: Fibrosis and Fracture
# Duplicate box found at index 2321: [655, 252, 858, 417]
# Corresponding lesions: Fibrosis and Fracture
# Duplicate box found at index 2322: [637, 184, 836, 349]
# Corresponding lesions: Fibrosis and Fracture
# Duplicate box found at index 2323: [64, 183, 411, 796]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2324: [73, 168, 456, 783]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2325: [85, 136, 458, 775]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2326: [96, 132, 450, 753]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2327: [38, 141, 403, 778]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2328: [81, 126, 474, 758]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2329: [154, 207, 474, 888]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2329: [587, 244, 849, 961]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2332: [138, 68, 453, 774]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2337: [244, 290, 446, 677]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2337: [592, 302, 835, 684]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2351: [616, 223, 891, 628]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2352: [575, 209, 863, 640]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2353: [616, 258, 916, 751]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2354: [648, 307, 883, 683]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2359: [598, 344, 895, 903]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2360: [569, 111, 865, 887]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2371: [605, 415, 891, 934]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2373: [545, 234, 845, 953]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2373: [81, 283, 393, 861]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2376: [589, 234, 878, 871]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2376: [112, 212, 469, 862]
# Corresponding lesions: Consolidation and Consolidation
# Duplicate box found at index 2377: [579, 229, 887, 921]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2379: [202, 331, 490, 793]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2382: [232, 184, 406, 365]
# Corresponding lesions: Fibrosis and Fracture
# Duplicate box found at index 2383: [181, 163, 388, 312]
# Corresponding lesions: Fibrosis and Fracture
# Duplicate box found at index 2384: [564, 223, 882, 799]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2384: [144, 233, 451, 833]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2389: [608, 111, 929, 767]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2391: [637, 95, 1012, 786]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2392: [471, 124, 797, 774]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2393: [605, 202, 942, 824]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2394: [243, 454, 464, 827]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2400: [112, 179, 443, 791]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2404: [559, 331, 792, 927]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2404: [152, 226, 425, 909]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2405: [606, 296, 873, 950]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2405: [249, 215, 529, 856]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2406: [616, 360, 834, 934]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2406: [246, 242, 500, 890]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2407: [484, 352, 748, 861]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2408: [618, 286, 920, 685]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2408: [112, 286, 406, 751]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2417: [151, 215, 475, 799]
# Corresponding lesions: Atelectasis and Consolidation
# Duplicate box found at index 2417: [151, 215, 475, 799]
# Corresponding lesions: Atelectasis and Effusion
# Duplicate box found at index 2418: [207, 173, 500, 835]
# Corresponding lesions: Atelectasis and Consolidation
# Duplicate box found at index 2418: [207, 173, 500, 835]
# Corresponding lesions: Atelectasis and Effusion
# Duplicate box found at index 2421: [144, 462, 453, 846]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2425: [553, 278, 842, 963]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2425: [112, 451, 451, 966]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2429: [569, 216, 887, 851]
# Corresponding lesions: Fibrosis and Emphysema
# Duplicate box found at index 2429: [167, 173, 484, 835]
# Corresponding lesions: Emphysema and Emphysema
# Duplicate box found at index 2430: [555, 136, 861, 804]
# Corresponding lesions: Fibrosis and Emphysema
# Duplicate box found at index 2430: [185, 132, 461, 759]
# Corresponding lesions: Emphysema and Emphysema
# Duplicate box found at index 2431: [606, 79, 912, 804]
# Corresponding lesions: Fibrosis and Emphysema
# Duplicate box found at index 2431: [204, 68, 508, 793]
# Corresponding lesions: Emphysema and Emphysema
# Duplicate box found at index 2432: [537, 208, 807, 859]
# Corresponding lesions: Fibrosis and Emphysema
# Duplicate box found at index 2432: [198, 189, 456, 825]
# Corresponding lesions: Emphysema and Emphysema
# Duplicate box found at index 2433: [658, 160, 986, 827]
# Corresponding lesions: Fibrosis and Emphysema
# Duplicate box found at index 2433: [249, 157, 566, 832]
# Corresponding lesions: Emphysema and Emphysema
# Duplicate box found at index 2439: [556, 50, 813, 640]
# Corresponding lesions: Fibrosis and Emphysema
# Duplicate box found at index 2439: [198, 95, 446, 590]
# Corresponding lesions: Emphysema and Emphysema
# Duplicate box found at index 2440: [551, 179, 752, 751]
# Corresponding lesions: Fibrosis and Emphysema
# Duplicate box found at index 2445: [576, 139, 897, 816]
# Corresponding lesions: Fibrosis and Emphysema
# Duplicate box found at index 2452: [128, 212, 501, 507]
# Corresponding lesions: Consolidation and Mass
# Duplicate box found at index 2453: [128, 178, 482, 476]
# Corresponding lesions: Consolidation and Mass
# Duplicate box found at index 2456: [555, 123, 800, 778]
# Corresponding lesions: Fibrosis and Consolidation
# Duplicate box found at index 2456: [142, 123, 453, 703]
# Corresponding lesions: Consolidation and Consolidation
# Duplicate box found at index 2457: [206, 241, 474, 822]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2457: [571, 210, 876, 796]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2461: [112, 468, 412, 636]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2462: [115, 371, 461, 604]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2463: [154, 202, 493, 585]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2464: [104, 136, 387, 808]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2465: [243, 543, 464, 798]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2466: [188, 425, 469, 735]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2467: [115, 350, 443, 627]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2473: [622, 139, 947, 636]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2474: [501, 383, 755, 761]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2474: [47, 415, 325, 701]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2475: [608, 338, 884, 732]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2475: [198, 417, 493, 716]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2477: [619, 171, 899, 830]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2478: [526, 153, 866, 623]
# Corresponding lesions: Fibrosis and Emphysema
# Duplicate box found at index 2478: [165, 132, 451, 598]
# Corresponding lesions: Emphysema and Emphysema
# Duplicate box found at index 2479: [624, 507, 842, 751]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2479: [227, 493, 433, 745]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2487: [574, 66, 878, 850]
# Corresponding lesions: Atelectasis and Effusion
# Duplicate box found at index 2488: [580, 76, 916, 874]
# Corresponding lesions: Atelectasis and Effusion
# Duplicate box found at index 2489: [503, 268, 826, 825]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2489: [65, 572, 383, 848]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2490: [555, 460, 857, 745]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2491: [555, 443, 857, 759]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2492: [616, 543, 945, 740]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2494: [559, 178, 958, 801]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2494: [194, 237, 456, 749]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2502: [601, 147, 881, 956]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2502: [125, 186, 451, 950]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2507: [600, 192, 891, 871]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2507: [186, 192, 487, 848]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2508: [550, 447, 844, 748]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2508: [167, 523, 438, 806]
# Corresponding lesions: Nodule and Effusion
# Duplicate box found at index 2509: [490, 404, 782, 791]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2511: [568, 171, 873, 740]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2520: [553, 449, 852, 661]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2521: [572, 360, 829, 630]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2522: [630, 108, 908, 956]
# Corresponding lesions: Fibrosis and Emphysema
# Duplicate box found at index 2522: [212, 150, 526, 924]
# Corresponding lesions: Emphysema and Emphysema
# Duplicate box found at index 2533: [487, 299, 808, 753]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2535: [593, 436, 868, 758]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2539: [136, 120, 408, 630]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2540: [563, 189, 802, 546]
# Corresponding lesions: Atelectasis and Mass
# Duplicate box found at index 2540: [104, 178, 466, 696]
# Corresponding lesions: Effusion and Emphysema
# Duplicate box found at index 2540: [104, 178, 466, 696]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2543: [598, 236, 916, 861]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2543: [109, 199, 438, 887]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2546: [606, 66, 915, 888]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2546: [106, 108, 475, 796]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2547: [527, 287, 832, 796]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2547: [97, 254, 448, 753]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2550: [51, 134, 424, 853]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2564: [169, 493, 443, 762]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2565: [614, 444, 844, 749]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2566: [611, 593, 916, 940]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2573: [622, 384, 844, 644]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2574: [598, 412, 840, 669]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2574: [209, 359, 456, 633]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2574: [209, 359, 456, 633]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2574: [450, 50, 513, 468]
# Corresponding lesions: Atelectasis and Effusion
# Duplicate box found at index 2576: [584, 422, 863, 748]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2577: [564, 347, 884, 638]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2579: [629, 525, 942, 769]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2581: [622, 205, 849, 761]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2581: [238, 244, 534, 769]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2582: [56, 554, 467, 940]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2582: [609, 464, 895, 956]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2588: [609, 438, 916, 822]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2588: [80, 509, 442, 838]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2589: [122, 266, 433, 904]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2590: [88, 476, 422, 867]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2592: [603, 428, 957, 927]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2592: [167, 577, 505, 938]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2593: [217, 413, 500, 906]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2594: [228, 252, 535, 911]
# Corresponding lesions: Atelectasis and Consolidation
# Duplicate box found at index 2594: [228, 252, 535, 911]
# Corresponding lesions: Atelectasis and Effusion
# Duplicate box found at index 2597: [102, 430, 417, 880]
# Corresponding lesions: Atelectasis and Effusion
# Duplicate box found at index 2607: [185, 612, 490, 751]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2608: [624, 257, 832, 745]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2608: [206, 221, 464, 714]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2609: [146, 504, 446, 644]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2610: [223, 317, 474, 737]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2613: [584, 378, 902, 790]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2615: [135, 602, 400, 874]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2616: [175, 447, 437, 782]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2617: [219, 371, 477, 586]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2618: [204, 318, 440, 664]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2635: [125, 275, 466, 733]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2637: [580, 670, 900, 900]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2647: [527, 318, 761, 850]
# Corresponding lesions: Fibrosis and Emphysema
# Duplicate box found at index 2647: [527, 318, 761, 850]
# Corresponding lesions: Fibrosis and Consolidation
# Duplicate box found at index 2647: [164, 174, 414, 733]
# Corresponding lesions: Emphysema and Emphysema
# Duplicate box found at index 2647: [164, 174, 414, 733]
# Corresponding lesions: Emphysema and Consolidation
# Duplicate box found at index 2648: [555, 302, 792, 862]
# Corresponding lesions: Fibrosis and Emphysema
# Duplicate box found at index 2648: [215, 223, 477, 796]
# Corresponding lesions: Emphysema and Emphysema
# Duplicate box found at index 2648: [215, 223, 477, 796]
# Corresponding lesions: Emphysema and Consolidation
# Duplicate box found at index 2649: [206, 294, 448, 877]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2649: [590, 357, 811, 956]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2649: [590, 357, 811, 956]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2652: [43, 205, 370, 649]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2652: [513, 289, 818, 544]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2652: [513, 289, 818, 544]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2653: [177, 153, 467, 682]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2653: [547, 192, 815, 628]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2653: [547, 192, 815, 628]
# Corresponding lesions: Consolidation and Consolidation
# Duplicate box found at index 2656: [642, 186, 947, 640]
# Corresponding lesions: Fibrosis and Emphysema
# Duplicate box found at index 2656: [642, 186, 947, 640]
# Corresponding lesions: Fibrosis and Consolidation
# Duplicate box found at index 2656: [165, 171, 495, 596]
# Corresponding lesions: Consolidation and Emphysema
# Duplicate box found at index 2656: [165, 171, 495, 596]
# Corresponding lesions: Consolidation and Consolidation
# Duplicate box found at index 2668: [547, 273, 887, 727]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2668: [56, 331, 370, 843]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2677: [614, 179, 920, 859]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2681: [563, 199, 839, 938]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2681: [94, 202, 400, 846]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2682: [569, 124, 849, 879]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2682: [120, 79, 459, 774]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2684: [553, 489, 823, 732]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2685: [527, 183, 771, 809]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2685: [144, 178, 409, 756]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2689: [606, 378, 934, 735]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2701: [94, 145, 409, 871]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2702: [519, 346, 789, 712]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2702: [109, 443, 395, 654]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2705: [127, 433, 461, 848]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2705: [553, 507, 839, 964]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2707: [122, 438, 456, 890]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2707: [576, 535, 881, 830]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2709: [595, 548, 850, 766]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2712: [138, 268, 400, 937]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2712: [556, 228, 831, 903]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2715: [574, 184, 836, 769]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2715: [160, 176, 458, 777]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2716: [619, 263, 894, 793]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2716: [207, 270, 480, 809]
# Corresponding lesions: Consolidation and Consolidation
# Duplicate box found at index 2719: [535, 202, 789, 929]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2719: [154, 205, 425, 848]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2721: [516, 212, 769, 853]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2721: [118, 218, 417, 827]
# Corresponding lesions: Consolidation and Consolidation
# Duplicate box found at index 2722: [568, 200, 818, 856]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2722: [172, 228, 451, 851]
# Corresponding lesions: Consolidation and Consolidation
# Duplicate box found at index 2723: [585, 233, 839, 935]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2723: [190, 284, 469, 895]
# Corresponding lesions: Consolidation and Consolidation
# Duplicate box found at index 2724: [553, 278, 819, 913]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2724: [180, 271, 430, 892]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2737: [614, 226, 887, 890]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2737: [146, 178, 477, 825]
# Corresponding lesions: Consolidation and Consolidation
# Duplicate box found at index 2738: [585, 178, 921, 904]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2738: [164, 183, 477, 885]
# Corresponding lesions: Consolidation and Consolidation
# Duplicate box found at index 2740: [655, 490, 996, 927]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2741: [611, 300, 881, 837]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2741: [220, 326, 492, 809]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2742: [640, 317, 863, 942]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2742: [248, 312, 484, 964]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2745: [595, 254, 861, 843]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2745: [212, 220, 487, 866]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2746: [416, 250, 668, 824]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2746: [64, 231, 330, 799]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2748: [151, 134, 471, 706]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2748: [550, 258, 784, 856]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2749: [606, 192, 844, 900]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2749: [223, 158, 495, 814]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2751: [629, 132, 975, 761]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2751: [233, 189, 529, 921]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2753: [627, 255, 887, 913]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2753: [175, 244, 496, 861]
# Corresponding lesions: Consolidation and Consolidation
# Duplicate box found at index 2755: [629, 244, 929, 777]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2755: [222, 234, 488, 824]
# Corresponding lesions: Consolidation and Consolidation
# Duplicate box found at index 2760: [555, 216, 768, 772]
# Corresponding lesions: Fibrosis and Consolidation
# Duplicate box found at index 2760: [190, 165, 430, 636]
# Corresponding lesions: Consolidation and Consolidation
# Duplicate box found at index 2765: [585, 260, 876, 892]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2765: [170, 239, 454, 930]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2766: [564, 305, 849, 861]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2766: [165, 321, 427, 877]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2767: [516, 360, 771, 964]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2767: [99, 350, 387, 890]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2778: [606, 158, 873, 906]
# Corresponding lesions: Fibrosis and Emphysema
# Duplicate box found at index 2778: [606, 158, 873, 906]
# Corresponding lesions: Fibrosis and Consolidation
# Duplicate box found at index 2778: [183, 142, 461, 883]
# Corresponding lesions: Consolidation and Emphysema
# Duplicate box found at index 2779: [632, 141, 929, 940]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2780: [582, 107, 861, 791]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2780: [131, 81, 464, 835]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2783: [563, 124, 882, 761]
# Corresponding lesions: Emphysema and Consolidation
# Duplicate box found at index 2783: [149, 124, 446, 659]
# Corresponding lesions: Consolidation and Consolidation
# Duplicate box found at index 2786: [547, 258, 803, 727]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2788: [94, 278, 451, 946]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2789: [39, 210, 485, 770]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2790: [120, 333, 487, 791]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2791: [598, 131, 873, 774]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2791: [232, 118, 490, 693]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2792: [555, 216, 849, 746]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2792: [157, 181, 453, 890]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2793: [568, 123, 849, 801]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2793: [175, 194, 454, 766]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2794: [590, 174, 839, 770]
# Corresponding lesions: Fibrosis and Consolidation
# Duplicate box found at index 2794: [193, 244, 446, 728]
# Corresponding lesions: Consolidation and Consolidation
# Duplicate box found at index 2797: [590, 357, 921, 874]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2797: [76, 317, 445, 858]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2798: [556, 239, 873, 825]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2799: [151, 179, 380, 727]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2799: [492, 273, 732, 678]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2800: [257, 538, 526, 716]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2802: [615, 375, 867, 659]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2802: [201, 300, 476, 615]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2803: [550, 246, 779, 840]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2805: [585, 145, 853, 827]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2807: [653, 497, 994, 877]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2812: [611, 426, 857, 724]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2812: [204, 176, 490, 686]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2817: [159, 455, 456, 748]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2818: [669, 220, 968, 956]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2818: [172, 247, 532, 942]
# Corresponding lesions: Consolidation and Consolidation
# Duplicate box found at index 2819: [663, 202, 916, 859]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2819: [148, 268, 450, 864]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2822: [603, 583, 987, 816]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2826: [561, 312, 836, 901]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2826: [216, 338, 484, 874]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2832: [642, 192, 887, 830]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2833: [177, 257, 432, 787]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2838: [642, 315, 957, 871]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2838: [112, 292, 521, 901]
# Corresponding lesions: Consolidation and Consolidation
# Duplicate box found at index 2839: [576, 313, 939, 677]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2839: [201, 326, 454, 761]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2840: [598, 472, 894, 707]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2840: [162, 371, 400, 749]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2846: [723, 204, 978, 759]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2847: [590, 363, 900, 783]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2847: [115, 373, 446, 743]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2848: [535, 386, 831, 864]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2851: [559, 124, 834, 851]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2851: [106, 68, 443, 877]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2852: [603, 202, 939, 848]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2852: [194, 189, 448, 862]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2853: [600, 323, 882, 806]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2853: [209, 307, 492, 783]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2860: [572, 299, 874, 727]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2861: [505, 204, 774, 827]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2861: [43, 223, 369, 814]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2864: [597, 249, 937, 795]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2865: [595, 328, 960, 619]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2867: [719, 749, 950, 887]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2868: [503, 397, 821, 906]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2868: [80, 396, 366, 959]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2871: [545, 557, 832, 735]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2873: [46, 237, 438, 911]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2874: [22, 186, 404, 872]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2875: [238, 110, 563, 866]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2876: [180, 228, 461, 822]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2878: [603, 205, 894, 740]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2881: [219, 449, 448, 728]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2881: [619, 399, 887, 698]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2884: [477, 82, 731, 808]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2884: [96, 47, 401, 743]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2886: [569, 494, 870, 778]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2890: [73, 501, 419, 880]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2890: [564, 661, 852, 942]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2891: [603, 654, 891, 929]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2892: [603, 241, 837, 812]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2892: [198, 218, 466, 758]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2898: [157, 86, 454, 685]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2899: [619, 485, 942, 833]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2899: [172, 538, 484, 908]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2902: [206, 260, 477, 648]
# Corresponding lesions: Atelectasis and Consolidation
# Duplicate box found at index 2902: [206, 260, 477, 648]
# Corresponding lesions: Atelectasis and Mass
# Duplicate box found at index 2902: [206, 260, 477, 648]
# Corresponding lesions: Atelectasis and Effusion
# Duplicate box found at index 2903: [558, 599, 863, 799]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2903: [139, 465, 409, 778]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2906: [603, 100, 839, 799]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2906: [154, 82, 485, 714]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2908: [165, 468, 487, 749]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2908: [639, 441, 915, 809]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2911: [509, 176, 849, 851]
# Corresponding lesions: Atelectasis and Consolidation
# Duplicate box found at index 2911: [509, 176, 849, 851]
# Corresponding lesions: Atelectasis and Effusion
# Duplicate box found at index 2915: [559, 162, 900, 738]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2915: [198, 202, 442, 812]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2919: [482, 246, 758, 809]
# Corresponding lesions: Fibrosis and Consolidation
# Duplicate box found at index 2921: [551, 207, 894, 830]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2921: [86, 244, 404, 856]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2922: [568, 226, 861, 854]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2922: [238, 234, 459, 880]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2926: [603, 118, 900, 806]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2927: [149, 426, 474, 845]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2929: [566, 352, 882, 770]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2930: [215, 434, 535, 611]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2931: [120, 352, 406, 938]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2932: [592, 229, 918, 825]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2932: [99, 231, 435, 843]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2936: [262, 210, 488, 774]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2945: [188, 312, 425, 890]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2945: [550, 312, 823, 871]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2946: [632, 275, 918, 698]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2947: [598, 315, 884, 762]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2948: [190, 367, 454, 719]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2952: [569, 278, 882, 688]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2953: [616, 539, 908, 812]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2953: [118, 657, 409, 824]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2960: [624, 349, 873, 845]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2961: [601, 140, 945, 727]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2962: [553, 195, 828, 853]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2962: [177, 226, 442, 874]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2964: [572, 449, 913, 832]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2964: [141, 360, 438, 848]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2967: [632, 423, 999, 727]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2968: [605, 572, 908, 822]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2972: [128, 197, 401, 833]
# Corresponding lesions: Atelectasis and Consolidation
# Duplicate box found at index 2972: [128, 197, 401, 833]
# Corresponding lesions: Atelectasis and Effusion
# Duplicate box found at index 2974: [551, 512, 847, 770]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2977: [170, 197, 467, 832]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2977: [577, 257, 847, 846]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2979: [555, 279, 836, 790]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2979: [138, 275, 421, 953]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2981: [576, 189, 891, 832]
# Corresponding lesions: Effusion and Consolidation
# Duplicate box found at index 2981: [182, 225, 464, 943]
# Corresponding lesions: Consolidation and Consolidation
# Duplicate box found at index 2982: [17, 560, 367, 946]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2982: [513, 527, 874, 804]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2983: [550, 404, 824, 822]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2986: [131, 250, 387, 693]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2987: [94, 139, 377, 662]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2988: [550, 141, 803, 677]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2991: [569, 71, 881, 745]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2991: [167, 39, 464, 767]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2992: [572, 270, 787, 693]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2992: [262, 246, 469, 735]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2995: [580, 111, 878, 644]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2996: [521, 441, 829, 945]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2996: [81, 465, 349, 934]
# Corresponding lesions: Effusion and Effusion
# Duplicate box found at index 2997: [559, 396, 847, 880]
# Corresponding lesions: Consolidation and Effusion
# Duplicate box found at index 2997: [96, 360, 361, 861]
# Corresponding lesions: Effusion and Effusion

# %%
df_train.head(20)
# Out:
#         image                                               path  \
# 0   36200.png  ..\data\versions\1\train_data\train-old\36200.png
# 1   36201.png  ..\data\versions\1\train_data\train-old\36201.png
# 2   36202.png  ..\data\versions\1\train_data\train-old\36202.png
# 3   36203.png  ..\data\versions\1\train_data\train-old\36203.png
# 4   36204.png  ..\data\versions\1\train_data\train-old\36204.png
# 5   36205.png  ..\data\versions\1\train_data\train-old\36205.png
# 6   36206.png  ..\data\versions\1\train_data\train-old\36206.png
# 7   36209.png  ..\data\versions\1\train_data\train-old\36209.png
# 8   36210.png  ..\data\versions\1\train_data\train-old\36210.png
# 9   36216.png  ..\data\versions\1\train_data\train-old\36216.png
# 10  36217.png  ..\data\versions\1\train_data\train-old\36217.png
# 11  36218.png  ..\data\versions\1\train_data\train-old\36218.png
# 12  36221.png  ..\data\versions\1\train_data\train-old\36221.png
# 13  36223.png  ..\data\versions\1\train_data\train-old\36223.png
# 14  36224.png  ..\data\versions\1\train_data\train-old\36224.png
# 15  36226.png  ..\data\versions\1\train_data\train-old\36226.png
# 16  36229.png  ..\data\versions\1\train_data\train-old\36229.png
# 17  36231.png  ..\data\versions\1\train_data\train-old\36231.png
# 18  36233.png  ..\data\versions\1\train_data\train-old\36233.png
# 19  36234.png  ..\data\versions\1\train_data\train-old\36234.png
#
#                                                  syms  \
# 0                                                  []
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4                                            [Nodule]
# 5   [Nodule, Nodule, Nodule, Nodule, Nodule, Nodul...
# 6                     [Nodule, Nodule, Consolidation]
# 7                      [Effusion, Effusion, Effusion]
# 8                                            [Nodule]
# 9                           [Consolidation, Effusion]
# 10                                                 []
# 11                               [Fibrosis, Fibrosis]
# 12                                                 []
# 13                                                 []
# 14  [Consolidation, Consolidation, Emphysema, Emph...
# 15                                                 []
# 16                                                 []
# 17                                    [Calcification]
# 18                                                 []
# 19                         [Atelectasis, Atelectasis]
#
#                                                 boxes
# 0                                                  []
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4                              [[233, 666, 258, 693]]
# 5   [[884, 223, 957, 299], [414, 208, 499, 267], [...
# 6   [[209, 594, 248, 643], [771, 508, 815, 568], [...
# 7   [[58, 515, 208, 659], [18, 605, 359, 802], [83...
# 8                              [[240, 303, 286, 356]]
# 9        [[224, 511, 445, 800], [127, 739, 452, 904]]
# 10                                                 []
# 11       [[611, 144, 674, 268], [412, 138, 490, 263]]
# 12                                                 []
# 13                                                 []
# 14  [[563, 66, 873, 981], [140, 16, 495, 927], [13...
# 15                                                 []
# 16                                                 []
# 17                             [[769, 489, 781, 499]]
# 18                                                 []
# 19       [[697, 696, 922, 762], [158, 738, 509, 799]]

# %%
# 建立疾病名稱到代號的映射字典
disease_names = set([disease for sublist in df_train["syms"] for disease in sublist])
disease_to_id = {disease: idx for idx, disease in enumerate(disease_names)}
print("Disease to ID mapping:", disease_to_id)

df_train["syms"] = df_train["syms"].apply(lambda x: [disease_to_id[disease] for disease in x])
df_test["syms"] = df_test["syms"].apply(lambda x: [disease_to_id[disease] for disease in x])
# Out:
# Disease to ID mapping: {'Consolidation': 0, 'Mass': 1, 'Emphysema': 2, 'Fibrosis': 3, 'Effusion': 4, 'Pneumothorax': 5, 'Nodule': 6, 'Atelectasis': 7, 'Calcification': 8, 'Fracture': 9}

# %%
df_train
# Out:
#           image                                               path  \
# 0     36200.png  ..\data\versions\1\train_data\train-old\36200.png
# 1     36201.png  ..\data\versions\1\train_data\train-old\36201.png
# 2     36202.png  ..\data\versions\1\train_data\train-old\36202.png
# 3     36203.png  ..\data\versions\1\train_data\train-old\36203.png
# 4     36204.png  ..\data\versions\1\train_data\train-old\36204.png
# ...         ...                                                ...
# 2996  70948.png  ..\data\versions\1\train_data\train-old\70948.png
# 2997  70949.png  ..\data\versions\1\train_data\train-old\70949.png
# 2998  70950.png  ..\data\versions\1\train_data\train-old\70950.png
# 2999  70954.png  ..\data\versions\1\train_data\train-old\70954.png
# 3000  70958.png  ..\data\versions\1\train_data\train-old\70958.png
#
#               syms                                              boxes
# 0               []                                                 []
# 1               []                                                 []
# 2               []                                                 []
# 3               []                                                 []
# 4              [6]                             [[233, 666, 258, 693]]
# ...            ...                                                ...
# 2996  [0, 4, 0, 4]  [[521, 441, 829, 945], [521, 441, 829, 945], [...
# 2997  [0, 4, 0, 4]  [[559, 396, 847, 880], [559, 396, 847, 880], [...
# 2998     [0, 8, 4]  [[637, 510, 824, 672], [748, 682, 771, 722], [...
# 2999        [0, 0]       [[603, 111, 858, 695], [254, 162, 479, 682]]
# 3000           [0]                             [[283, 593, 421, 751]]
#
# [3001 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split

# split dataset into train and val
train, val = train_test_split(
    df_train, 
    test_size=0.2,   # 設定 val 集比例
    random_state=25  # 固定隨機種子，確保可重現
)

# %%
import numpy as np
import cv2
import torch
from torch.utils.data import TensorDataset, DataLoader

def dataLoad(dfPath):
    """
    加載數據並處理圖像，同時生成 Faster R-CNN 的 `targets` 格式。
    
    Args:
        dfPath (pd.DataFrame): 包含圖像路徑和標籤的 DataFrame。

    Returns:
        tuple: 處理後的圖像數據 (x) 和目標數據 (targets)。
    """
    # 提取文件路徑
    paths = dfPath["path"].values
    images = []  # 存儲處理後的圖像
    targets = []  # 存儲目標數據

    for j in range(len(paths)):
        # 加載圖像
        syms = dfPath.iloc[j]["syms"]  # 獲取疾病類別
        boxes = dfPath.iloc[j]["boxes"]  # 獲取邊界框

        # 過濾沒有邊界框的樣本
        if len(boxes) == 0:
            print(f"Skipping index {j}: No bounding boxes found.")
            continue
        img = cv2.imread(paths[j], cv2.IMREAD_GRAYSCALE)  # 加載為灰度圖像
        
        # 調整大小
        img_resized = cv2.resize(img, (128, 128))  # 使用 OpenCV 進行縮放
        
        # 標準化圖像到 [0, 1] 範圍
        img_resized = img_resized / 255.0
        images.append(img_resized)

        # 獲取疾病類別和邊界框
        

        # 構建 Faster R-CNN 的 `targets` 格式
        target = {
            "boxes": torch.tensor(boxes, dtype=torch.float32),  # 邊界框
            "labels": torch.tensor(syms, dtype=torch.int64)      # 疾病類別
        }
        targets.append(target)

    # 將圖像數據轉換為 PyTorch 張量
    x = torch.tensor(np.array(images, dtype=np.float32)).unsqueeze(1)  # 添加通道維度

    return x, targets

# 修改後的加載數據
x_train, y_train = dataLoad(train)
x_val, y_val = dataLoad(val)



print(f"Train data shape: {x_train.shape}, Train targets count: {len(y_train)}")
print(f"Validation data shape: {x_val.shape}, Validation targets count: {len(y_val)}")
# Out:
# Skipping index 16: No bounding boxes found.
# Skipping index 18: No bounding boxes found.
# Skipping index 23: No bounding boxes found.
# Skipping index 26: No bounding boxes found.
# Skipping index 39: No bounding boxes found.
# Skipping index 40: No bounding boxes found.
# Skipping index 45: No bounding boxes found.
# Skipping index 50: No bounding boxes found.
# Skipping index 60: No bounding boxes found.
# Skipping index 69: No bounding boxes found.
# Skipping index 70: No bounding boxes found.
# Skipping index 72: No bounding boxes found.
# Skipping index 74: No bounding boxes found.
# Skipping index 75: No bounding boxes found.
# Skipping index 77: No bounding boxes found.
# Skipping index 81: No bounding boxes found.
# Skipping index 87: No bounding boxes found.
# Skipping index 88: No bounding boxes found.
# Skipping index 92: No bounding boxes found.
# Skipping index 99: No bounding boxes found.
# Skipping index 104: No bounding boxes found.
# Skipping index 114: No bounding boxes found.
# Skipping index 115: No bounding boxes found.
# Skipping index 125: No bounding boxes found.
# Skipping index 128: No bounding boxes found.
# Skipping index 129: No bounding boxes found.
# Skipping index 132: No bounding boxes found.
# Skipping index 134: No bounding boxes found.
# Skipping index 136: No bounding boxes found.
# Skipping index 138: No bounding boxes found.
# Skipping index 139: No bounding boxes found.
# Skipping index 141: No bounding boxes found.
# Skipping index 151: No bounding boxes found.
# Skipping index 152: No bounding boxes found.
# Skipping index 153: No bounding boxes found.
# Skipping index 154: No bounding boxes found.
# Skipping index 159: No bounding boxes found.
# Skipping index 178: No bounding boxes found.
# Skipping index 189: No bounding boxes found.
# Skipping index 194: No bounding boxes found.
# Skipping index 198: No bounding boxes found.
# Skipping index 212: No bounding boxes found.
# Skipping index 215: No bounding boxes found.
# Skipping index 216: No bounding boxes found.
# Skipping index 217: No bounding boxes found.
# Skipping index 224: No bounding boxes found.
# Skipping index 228: No bounding boxes found.
# Skipping index 230: No bounding boxes found.
# Skipping index 239: No bounding boxes found.
# Skipping index 241: No bounding boxes found.
# Skipping index 246: No bounding boxes found.
# Skipping index 255: No bounding boxes found.
# Skipping index 258: No bounding boxes found.
# Skipping index 259: No bounding boxes found.
# Skipping index 262: No bounding boxes found.
# Skipping index 263: No bounding boxes found.
# Skipping index 268: No bounding boxes found.
# Skipping index 279: No bounding boxes found.
# Skipping index 282: No bounding boxes found.
# Skipping index 284: No bounding boxes found.
# Skipping index 286: No bounding boxes found.
# Skipping index 296: No bounding boxes found.
# Skipping index 299: No bounding boxes found.
# Skipping index 302: No bounding boxes found.
# Skipping index 308: No bounding boxes found.
# Skipping index 310: No bounding boxes found.
# Skipping index 312: No bounding boxes found.
# Skipping index 316: No bounding boxes found.
# Skipping index 317: No bounding boxes found.
# Skipping index 322: No bounding boxes found.
# Skipping index 338: No bounding boxes found.
# Skipping index 344: No bounding boxes found.
# Skipping index 346: No bounding boxes found.
# Skipping index 349: No bounding boxes found.
# Skipping index 356: No bounding boxes found.
# Skipping index 360: No bounding boxes found.
# Skipping index 365: No bounding boxes found.
# Skipping index 368: No bounding boxes found.
# Skipping index 369: No bounding boxes found.
# Skipping index 379: No bounding boxes found.
# Skipping index 381: No bounding boxes found.
# Skipping index 389: No bounding boxes found.
# Skipping index 398: No bounding boxes found.
# Skipping index 400: No bounding boxes found.
# Skipping index 403: No bounding boxes found.
# Skipping index 408: No bounding boxes found.
# Skipping index 409: No bounding boxes found.
# Skipping index 415: No bounding boxes found.
# Skipping index 416: No bounding boxes found.
# Skipping index 421: No bounding boxes found.
# Skipping index 444: No bounding boxes found.
# Skipping index 448: No bounding boxes found.
# Skipping index 450: No bounding boxes found.
# Skipping index 453: No bounding boxes found.
# Skipping index 461: No bounding boxes found.
# Skipping index 462: No bounding boxes found.
# Skipping index 467: No bounding boxes found.
# Skipping index 476: No bounding boxes found.
# Skipping index 483: No bounding boxes found.
# Skipping index 486: No bounding boxes found.
# Skipping index 487: No bounding boxes found.
# Skipping index 489: No bounding boxes found.
# Skipping index 493: No bounding boxes found.
# Skipping index 505: No bounding boxes found.
# Skipping index 511: No bounding boxes found.
# Skipping index 519: No bounding boxes found.
# Skipping index 531: No bounding boxes found.
# Skipping index 536: No bounding boxes found.
# Skipping index 548: No bounding boxes found.
# Skipping index 550: No bounding boxes found.
# Skipping index 568: No bounding boxes found.
# Skipping index 576: No bounding boxes found.
# Skipping index 581: No bounding boxes found.
# Skipping index 588: No bounding boxes found.
# Skipping index 591: No bounding boxes found.
# Skipping index 593: No bounding boxes found.
# Skipping index 602: No bounding boxes found.
# Skipping index 610: No bounding boxes found.
# Skipping index 613: No bounding boxes found.
# Skipping index 614: No bounding boxes found.
# Skipping index 615: No bounding boxes found.
# Skipping index 618: No bounding boxes found.
# Skipping index 621: No bounding boxes found.
# Skipping index 626: No bounding boxes found.
# Skipping index 629: No bounding boxes found.
# Skipping index 634: No bounding boxes found.
# Skipping index 642: No bounding boxes found.
# Skipping index 645: No bounding boxes found.
# Skipping index 648: No bounding boxes found.
# Skipping index 649: No bounding boxes found.
# Skipping index 651: No bounding boxes found.
# Skipping index 655: No bounding boxes found.
# Skipping index 657: No bounding boxes found.
# Skipping index 658: No bounding boxes found.
# Skipping index 664: No bounding boxes found.
# Skipping index 668: No bounding boxes found.
# Skipping index 675: No bounding boxes found.
# Skipping index 678: No bounding boxes found.
# Skipping index 682: No bounding boxes found.
# Skipping index 685: No bounding boxes found.
# Skipping index 687: No bounding boxes found.
# Skipping index 720: No bounding boxes found.
# Skipping index 733: No bounding boxes found.
# Skipping index 741: No bounding boxes found.
# Skipping index 743: No bounding boxes found.
# Skipping index 745: No bounding boxes found.
# Skipping index 747: No bounding boxes found.
# Skipping index 749: No bounding boxes found.
# Skipping index 750: No bounding boxes found.
# Skipping index 755: No bounding boxes found.
# Skipping index 756: No bounding boxes found.
# Skipping index 758: No bounding boxes found.
# Skipping index 761: No bounding boxes found.
# Skipping index 764: No bounding boxes found.
# Skipping index 772: No bounding boxes found.
# Skipping index 777: No bounding boxes found.
# Skipping index 788: No bounding boxes found.
# Skipping index 790: No bounding boxes found.
# Skipping index 794: No bounding boxes found.
# Skipping index 803: No bounding boxes found.
# Skipping index 805: No bounding boxes found.
# Skipping index 807: No bounding boxes found.
# Skipping index 816: No bounding boxes found.
# Skipping index 822: No bounding boxes found.
# Skipping index 824: No bounding boxes found.
# Skipping index 825: No bounding boxes found.
# Skipping index 829: No bounding boxes found.
# Skipping index 835: No bounding boxes found.
# Skipping index 839: No bounding boxes found.
# Skipping index 841: No bounding boxes found.
# Skipping index 844: No bounding boxes found.
# Skipping index 845: No bounding boxes found.
# Skipping index 847: No bounding boxes found.
# Skipping index 848: No bounding boxes found.
# Skipping index 850: No bounding boxes found.
# Skipping index 851: No bounding boxes found.
# Skipping index 852: No bounding boxes found.
# Skipping index 853: No bounding boxes found.
# Skipping index 854: No bounding boxes found.
# Skipping index 855: No bounding boxes found.
# Skipping index 856: No bounding boxes found.
# Skipping index 858: No bounding boxes found.
# Skipping index 864: No bounding boxes found.
# Skipping index 865: No bounding boxes found.
# Skipping index 877: No bounding boxes found.
# Skipping index 878: No bounding boxes found.
# Skipping index 879: No bounding boxes found.
# Skipping index 880: No bounding boxes found.
# Skipping index 882: No bounding boxes found.
# Skipping index 883: No bounding boxes found.
# Skipping index 892: No bounding boxes found.
# Skipping index 893: No bounding boxes found.
# Skipping index 900: No bounding boxes found.
# Skipping index 902: No bounding boxes found.
# Skipping index 903: No bounding boxes found.
# Skipping index 918: No bounding boxes found.
# Skipping index 919: No bounding boxes found.
# Skipping index 921: No bounding boxes found.
# Skipping index 927: No bounding boxes found.
# Skipping index 936: No bounding boxes found.
# Skipping index 946: No bounding boxes found.
# Skipping index 957: No bounding boxes found.
# Skipping index 966: No bounding boxes found.
# Skipping index 972: No bounding boxes found.
# Skipping index 977: No bounding boxes found.
# Skipping index 978: No bounding boxes found.
# Skipping index 982: No bounding boxes found.
# Skipping index 990: No bounding boxes found.
# Skipping index 995: No bounding boxes found.
# Skipping index 998: No bounding boxes found.
# Skipping index 1004: No bounding boxes found.
# Skipping index 1006: No bounding boxes found.
# Skipping index 1007: No bounding boxes found.
# Skipping index 1008: No bounding boxes found.
# Skipping index 1010: No bounding boxes found.
# Skipping index 1014: No bounding boxes found.
# Skipping index 1015: No bounding boxes found.
# Skipping index 1024: No bounding boxes found.
# Skipping index 1025: No bounding boxes found.
# Skipping index 1027: No bounding boxes found.
# Skipping index 1032: No bounding boxes found.
# Skipping index 1033: No bounding boxes found.
# Skipping index 1034: No bounding boxes found.
# Skipping index 1035: No bounding boxes found.
# Skipping index 1042: No bounding boxes found.
# Skipping index 1048: No bounding boxes found.
# Skipping index 1052: No bounding boxes found.
# Skipping index 1054: No bounding boxes found.
# Skipping index 1055: No bounding boxes found.
# Skipping index 1056: No bounding boxes found.
# Skipping index 1059: No bounding boxes found.
# Skipping index 1061: No bounding boxes found.
# Skipping index 1064: No bounding boxes found.
# Skipping index 1065: No bounding boxes found.
# Skipping index 1073: No bounding boxes found.
# Skipping index 1077: No bounding boxes found.
# Skipping index 1081: No bounding boxes found.
# Skipping index 1085: No bounding boxes found.
# Skipping index 1091: No bounding boxes found.
# Skipping index 1096: No bounding boxes found.
# Skipping index 1101: No bounding boxes found.
# Skipping index 1105: No bounding boxes found.
# Skipping index 1106: No bounding boxes found.
# Skipping index 1109: No bounding boxes found.
# Skipping index 1110: No bounding boxes found.
# Skipping index 1114: No bounding boxes found.
# Skipping index 1118: No bounding boxes found.
# Skipping index 1122: No bounding boxes found.
# Skipping index 1124: No bounding boxes found.
# Skipping index 1128: No bounding boxes found.
# Skipping index 1129: No bounding boxes found.
# Skipping index 1130: No bounding boxes found.
# Skipping index 1138: No bounding boxes found.
# Skipping index 1140: No bounding boxes found.
# Skipping index 1146: No bounding boxes found.
# Skipping index 1149: No bounding boxes found.
# Skipping index 1155: No bounding boxes found.
# Skipping index 1165: No bounding boxes found.
# Skipping index 1167: No bounding boxes found.
# Skipping index 1171: No bounding boxes found.
# Skipping index 1177: No bounding boxes found.
# Skipping index 1178: No bounding boxes found.
# Skipping index 1180: No bounding boxes found.
# Skipping index 1183: No bounding boxes found.
# Skipping index 1184: No bounding boxes found.
# Skipping index 1185: No bounding boxes found.
# Skipping index 1188: No bounding boxes found.
# Skipping index 1191: No bounding boxes found.
# Skipping index 1194: No bounding boxes found.
# Skipping index 1201: No bounding boxes found.
# Skipping index 1205: No bounding boxes found.
# Skipping index 1206: No bounding boxes found.
# Skipping index 1207: No bounding boxes found.
# Skipping index 1212: No bounding boxes found.
# Skipping index 1215: No bounding boxes found.
# Skipping index 1220: No bounding boxes found.
# Skipping index 1223: No bounding boxes found.
# Skipping index 1227: No bounding boxes found.
# Skipping index 1231: No bounding boxes found.
# Skipping index 1240: No bounding boxes found.
# Skipping index 1250: No bounding boxes found.
# Skipping index 1251: No bounding boxes found.
# Skipping index 1255: No bounding boxes found.
# Skipping index 1270: No bounding boxes found.
# Skipping index 1286: No bounding boxes found.
# Skipping index 1287: No bounding boxes found.
# Skipping index 1288: No bounding boxes found.
# Skipping index 1293: No bounding boxes found.
# Skipping index 1299: No bounding boxes found.
# Skipping index 1307: No bounding boxes found.
# Skipping index 1311: No bounding boxes found.
# Skipping index 1315: No bounding boxes found.
# Skipping index 1318: No bounding boxes found.
# Skipping index 1319: No bounding boxes found.
# Skipping index 1321: No bounding boxes found.
# Skipping index 1331: No bounding boxes found.
# Skipping index 1338: No bounding boxes found.
# Skipping index 1343: No bounding boxes found.
# Skipping index 1344: No bounding boxes found.
# Skipping index 1350: No bounding boxes found.
# Skipping index 1352: No bounding boxes found.
# Skipping index 1353: No bounding boxes found.
# Skipping index 1368: No bounding boxes found.
# Skipping index 1383: No bounding boxes found.
# Skipping index 1385: No bounding boxes found.
# Skipping index 1389: No bounding boxes found.
# Skipping index 1391: No bounding boxes found.
# Skipping index 1395: No bounding boxes found.
# Skipping index 1402: No bounding boxes found.
# Skipping index 1413: No bounding boxes found.
# Skipping index 1416: No bounding boxes found.
# Skipping index 1417: No bounding boxes found.
# Skipping index 1434: No bounding boxes found.
# Skipping index 1435: No bounding boxes found.
# Skipping index 1437: No bounding boxes found.
# Skipping index 1442: No bounding boxes found.
# Skipping index 1443: No bounding boxes found.
# Skipping index 1448: No bounding boxes found.
# Skipping index 1453: No bounding boxes found.
# Skipping index 1463: No bounding boxes found.
# Skipping index 1464: No bounding boxes found.
# Skipping index 1466: No bounding boxes found.
# Skipping index 1468: No bounding boxes found.
# Skipping index 1472: No bounding boxes found.
# Skipping index 1473: No bounding boxes found.
# Skipping index 1478: No bounding boxes found.
# Skipping index 1479: No bounding boxes found.
# Skipping index 1480: No bounding boxes found.
# Skipping index 1483: No bounding boxes found.
# Skipping index 1485: No bounding boxes found.
# Skipping index 1487: No bounding boxes found.
# Skipping index 1497: No bounding boxes found.
# Skipping index 1499: No bounding boxes found.
# Skipping index 1502: No bounding boxes found.
# Skipping index 1512: No bounding boxes found.
# Skipping index 1515: No bounding boxes found.
# Skipping index 1518: No bounding boxes found.
# Skipping index 1521: No bounding boxes found.
# Skipping index 1527: No bounding boxes found.
# Skipping index 1528: No bounding boxes found.
# Skipping index 1532: No bounding boxes found.
# Skipping index 1536: No bounding boxes found.
# Skipping index 1542: No bounding boxes found.
# Skipping index 1547: No bounding boxes found.
# Skipping index 1557: No bounding boxes found.
# Skipping index 1562: No bounding boxes found.
# Skipping index 1564: No bounding boxes found.
# Skipping index 1566: No bounding boxes found.
# Skipping index 1567: No bounding boxes found.
# Skipping index 1568: No bounding boxes found.
# Skipping index 1581: No bounding boxes found.
# Skipping index 1589: No bounding boxes found.
# Skipping index 1590: No bounding boxes found.
# Skipping index 1602: No bounding boxes found.
# Skipping index 1606: No bounding boxes found.
# Skipping index 1608: No bounding boxes found.
# Skipping index 1611: No bounding boxes found.
# Skipping index 1613: No bounding boxes found.
# Skipping index 1614: No bounding boxes found.
# Skipping index 1615: No bounding boxes found.
# Skipping index 1616: No bounding boxes found.
# Skipping index 1617: No bounding boxes found.
# Skipping index 1619: No bounding boxes found.
# Skipping index 1623: No bounding boxes found.
# Skipping index 1624: No bounding boxes found.
# Skipping index 1630: No bounding boxes found.
# Skipping index 1639: No bounding boxes found.
# Skipping index 1642: No bounding boxes found.
# Skipping index 1653: No bounding boxes found.
# Skipping index 1656: No bounding boxes found.
# Skipping index 1662: No bounding boxes found.
# Skipping index 1663: No bounding boxes found.
# Skipping index 1665: No bounding boxes found.
# Skipping index 1674: No bounding boxes found.
# Skipping index 1677: No bounding boxes found.
# Skipping index 1679: No bounding boxes found.
# Skipping index 1680: No bounding boxes found.
# Skipping index 1681: No bounding boxes found.
# Skipping index 1691: No bounding boxes found.
# Skipping index 1698: No bounding boxes found.
# Skipping index 1702: No bounding boxes found.
# Skipping index 1703: No bounding boxes found.
# Skipping index 1711: No bounding boxes found.
# Skipping index 1712: No bounding boxes found.
# Skipping index 1714: No bounding boxes found.
# Skipping index 1723: No bounding boxes found.
# Skipping index 1728: No bounding boxes found.
# Skipping index 1729: No bounding boxes found.
# Skipping index 1733: No bounding boxes found.
# Skipping index 1742: No bounding boxes found.
# Skipping index 1748: No bounding boxes found.
# Skipping index 1753: No bounding boxes found.
# Skipping index 1755: No bounding boxes found.
# Skipping index 1756: No bounding boxes found.
# Skipping index 1762: No bounding boxes found.
# Skipping index 1766: No bounding boxes found.
# Skipping index 1771: No bounding boxes found.
# Skipping index 1776: No bounding boxes found.
# Skipping index 1777: No bounding boxes found.
# Skipping index 1781: No bounding boxes found.
# Skipping index 1795: No bounding boxes found.
# Skipping index 1797: No bounding boxes found.
# Skipping index 1800: No bounding boxes found.
# Skipping index 1802: No bounding boxes found.
# Skipping index 1812: No bounding boxes found.
# Skipping index 1813: No bounding boxes found.
# Skipping index 1815: No bounding boxes found.
# Skipping index 1823: No bounding boxes found.
# Skipping index 1828: No bounding boxes found.
# Skipping index 1830: No bounding boxes found.
# Skipping index 1832: No bounding boxes found.
# Skipping index 1834: No bounding boxes found.
# Skipping index 1838: No bounding boxes found.
# Skipping index 1841: No bounding boxes found.
# Skipping index 1851: No bounding boxes found.
# Skipping index 1852: No bounding boxes found.
# Skipping index 1855: No bounding boxes found.
# Skipping index 1856: No bounding boxes found.
# Skipping index 1859: No bounding boxes found.
# Skipping index 1876: No bounding boxes found.
# Skipping index 1885: No bounding boxes found.
# Skipping index 1894: No bounding boxes found.
# Skipping index 1895: No bounding boxes found.
# Skipping index 1896: No bounding boxes found.
# Skipping index 1901: No bounding boxes found.
# Skipping index 1905: No bounding boxes found.
# Skipping index 1908: No bounding boxes found.
# Skipping index 1911: No bounding boxes found.
# Skipping index 1920: No bounding boxes found.
# Skipping index 1922: No bounding boxes found.
# Skipping index 1923: No bounding boxes found.
# Skipping index 1938: No bounding boxes found.
# Skipping index 1952: No bounding boxes found.
# Skipping index 1955: No bounding boxes found.
# Skipping index 1957: No bounding boxes found.
# Skipping index 1960: No bounding boxes found.
# Skipping index 1964: No bounding boxes found.
# Skipping index 1968: No bounding boxes found.
# Skipping index 1969: No bounding boxes found.
# Skipping index 1977: No bounding boxes found.
# Skipping index 1978: No bounding boxes found.
# Skipping index 1981: No bounding boxes found.
# Skipping index 1986: No bounding boxes found.
# Skipping index 1988: No bounding boxes found.
# Skipping index 1989: No bounding boxes found.
# Skipping index 1999: No bounding boxes found.
# Skipping index 2001: No bounding boxes found.
# Skipping index 2014: No bounding boxes found.
# Skipping index 2017: No bounding boxes found.
# Skipping index 2018: No bounding boxes found.
# Skipping index 2035: No bounding boxes found.
# Skipping index 2056: No bounding boxes found.
# Skipping index 2067: No bounding boxes found.
# Skipping index 2073: No bounding boxes found.
# Skipping index 2089: No bounding boxes found.
# Skipping index 2091: No bounding boxes found.
# Skipping index 2094: No bounding boxes found.
# Skipping index 2096: No bounding boxes found.
# Skipping index 2098: No bounding boxes found.
# Skipping index 2101: No bounding boxes found.
# Skipping index 2102: No bounding boxes found.
# Skipping index 2107: No bounding boxes found.
# Skipping index 2114: No bounding boxes found.
# Skipping index 2116: No bounding boxes found.
# Skipping index 2118: No bounding boxes found.
# Skipping index 2126: No bounding boxes found.
# Skipping index 2132: No bounding boxes found.
# Skipping index 2136: No bounding boxes found.
# Skipping index 2141: No bounding boxes found.
# Skipping index 2144: No bounding boxes found.
# Skipping index 2145: No bounding boxes found.
# Skipping index 2155: No bounding boxes found.
# Skipping index 2161: No bounding boxes found.
# Skipping index 2172: No bounding boxes found.
# Skipping index 2175: No bounding boxes found.
# Skipping index 2176: No bounding boxes found.
# Skipping index 2180: No bounding boxes found.
# Skipping index 2183: No bounding boxes found.
# Skipping index 2192: No bounding boxes found.
# Skipping index 2193: No bounding boxes found.
# Skipping index 2196: No bounding boxes found.
# Skipping index 2197: No bounding boxes found.
# Skipping index 2202: No bounding boxes found.
# Skipping index 2208: No bounding boxes found.
# Skipping index 2210: No bounding boxes found.
# Skipping index 2220: No bounding boxes found.
# Skipping index 2222: No bounding boxes found.
# Skipping index 2224: No bounding boxes found.
# Skipping index 2225: No bounding boxes found.
# Skipping index 2226: No bounding boxes found.
# Skipping index 2233: No bounding boxes found.
# Skipping index 2234: No bounding boxes found.
# Skipping index 2236: No bounding boxes found.
# Skipping index 2243: No bounding boxes found.
# Skipping index 2245: No bounding boxes found.
# Skipping index 2246: No bounding boxes found.
# Skipping index 2248: No bounding boxes found.
# Skipping index 2249: No bounding boxes found.
# Skipping index 2255: No bounding boxes found.
# Skipping index 2258: No bounding boxes found.
# Skipping index 2264: No bounding boxes found.
# Skipping index 2273: No bounding boxes found.
# Skipping index 2275: No bounding boxes found.
# Skipping index 2282: No bounding boxes found.
# Skipping index 2293: No bounding boxes found.
# Skipping index 2295: No bounding boxes found.
# Skipping index 2311: No bounding boxes found.
# Skipping index 2312: No bounding boxes found.
# Skipping index 2319: No bounding boxes found.
# Skipping index 2321: No bounding boxes found.
# Skipping index 2324: No bounding boxes found.
# Skipping index 2341: No bounding boxes found.
# Skipping index 2343: No bounding boxes found.
# Skipping index 2345: No bounding boxes found.
# Skipping index 2348: No bounding boxes found.
# Skipping index 2349: No bounding boxes found.
# Skipping index 2351: No bounding boxes found.
# Skipping index 2352: No bounding boxes found.
# Skipping index 2355: No bounding boxes found.
# Skipping index 2358: No bounding boxes found.
# Skipping index 2368: No bounding boxes found.
# Skipping index 2376: No bounding boxes found.
# Skipping index 2377: No bounding boxes found.
# Skipping index 2381: No bounding boxes found.
# Skipping index 2382: No bounding boxes found.
# Skipping index 2393: No bounding boxes found.
# Skipping index 2394: No bounding boxes found.
# Skipping index 5: No bounding boxes found.
# Skipping index 10: No bounding boxes found.
# Skipping index 14: No bounding boxes found.
# Skipping index 16: No bounding boxes found.
# Skipping index 20: No bounding boxes found.
# Skipping index 21: No bounding boxes found.
# Skipping index 31: No bounding boxes found.
# Skipping index 40: No bounding boxes found.
# Skipping index 43: No bounding boxes found.
# Skipping index 44: No bounding boxes found.
# Skipping index 46: No bounding boxes found.
# Skipping index 47: No bounding boxes found.
# Skipping index 50: No bounding boxes found.
# Skipping index 52: No bounding boxes found.
# Skipping index 53: No bounding boxes found.
# Skipping index 58: No bounding boxes found.
# Skipping index 59: No bounding boxes found.
# Skipping index 65: No bounding boxes found.
# Skipping index 66: No bounding boxes found.
# Skipping index 70: No bounding boxes found.
# Skipping index 73: No bounding boxes found.
# Skipping index 74: No bounding boxes found.
# Skipping index 77: No bounding boxes found.
# Skipping index 81: No bounding boxes found.
# Skipping index 82: No bounding boxes found.
# Skipping index 86: No bounding boxes found.
# Skipping index 87: No bounding boxes found.
# Skipping index 95: No bounding boxes found.
# Skipping index 105: No bounding boxes found.
# Skipping index 107: No bounding boxes found.
# Skipping index 112: No bounding boxes found.
# Skipping index 114: No bounding boxes found.
# Skipping index 115: No bounding boxes found.
# Skipping index 116: No bounding boxes found.
# Skipping index 125: No bounding boxes found.
# Skipping index 130: No bounding boxes found.
# Skipping index 132: No bounding boxes found.
# Skipping index 133: No bounding boxes found.
# Skipping index 143: No bounding boxes found.
# Skipping index 144: No bounding boxes found.
# Skipping index 145: No bounding boxes found.
# Skipping index 147: No bounding boxes found.
# Skipping index 148: No bounding boxes found.
# Skipping index 151: No bounding boxes found.
# Skipping index 153: No bounding boxes found.
# Skipping index 156: No bounding boxes found.
# Skipping index 157: No bounding boxes found.
# Skipping index 160: No bounding boxes found.
# Skipping index 161: No bounding boxes found.
# Skipping index 162: No bounding boxes found.
# Skipping index 169: No bounding boxes found.
# Skipping index 172: No bounding boxes found.
# Skipping index 177: No bounding boxes found.
# Skipping index 180: No bounding boxes found.
# Skipping index 182: No bounding boxes found.
# Skipping index 184: No bounding boxes found.
# Skipping index 203: No bounding boxes found.
# Skipping index 205: No bounding boxes found.
# Skipping index 206: No bounding boxes found.
# Skipping index 207: No bounding boxes found.
# Skipping index 217: No bounding boxes found.
# Skipping index 219: No bounding boxes found.
# Skipping index 225: No bounding boxes found.
# Skipping index 236: No bounding boxes found.
# Skipping index 239: No bounding boxes found.
# Skipping index 243: No bounding boxes found.
# Skipping index 245: No bounding boxes found.
# Skipping index 246: No bounding boxes found.
# Skipping index 247: No bounding boxes found.
# Skipping index 249: No bounding boxes found.
# Skipping index 252: No bounding boxes found.
# Skipping index 256: No bounding boxes found.
# Skipping index 260: No bounding boxes found.
# Skipping index 262: No bounding boxes found.
# Skipping index 264: No bounding boxes found.
# Skipping index 272: No bounding boxes found.
# Skipping index 274: No bounding boxes found.
# Skipping index 292: No bounding boxes found.
# Skipping index 296: No bounding boxes found.
# Skipping index 298: No bounding boxes found.
# Skipping index 300: No bounding boxes found.
# Skipping index 303: No bounding boxes found.
# Skipping index 304: No bounding boxes found.
# Skipping index 306: No bounding boxes found.
# Skipping index 309: No bounding boxes found.
# Skipping index 313: No bounding boxes found.
# Skipping index 315: No bounding boxes found.
# Skipping index 321: No bounding boxes found.
# Skipping index 323: No bounding boxes found.
# Skipping index 329: No bounding boxes found.
# Skipping index 330: No bounding boxes found.
# Skipping index 332: No bounding boxes found.
# Skipping index 337: No bounding boxes found.
# Skipping index 338: No bounding boxes found.
# Skipping index 343: No bounding boxes found.
# Skipping index 359: No bounding boxes found.
# Skipping index 361: No bounding boxes found.
# Skipping index 372: No bounding boxes found.
# Skipping index 380: No bounding boxes found.
# Skipping index 381: No bounding boxes found.
# Skipping index 389: No bounding boxes found.
# Skipping index 402: No bounding boxes found.
# Skipping index 413: No bounding boxes found.
# Skipping index 415: No bounding boxes found.
# Skipping index 416: No bounding boxes found.
# Skipping index 420: No bounding boxes found.
# Skipping index 421: No bounding boxes found.
# Skipping index 426: No bounding boxes found.
# Skipping index 428: No bounding boxes found.
# Skipping index 434: No bounding boxes found.
# Skipping index 436: No bounding boxes found.
# Skipping index 443: No bounding boxes found.
# Skipping index 454: No bounding boxes found.
# Skipping index 455: No bounding boxes found.
# Skipping index 456: No bounding boxes found.
# Skipping index 457: No bounding boxes found.
# Skipping index 458: No bounding boxes found.
# Skipping index 460: No bounding boxes found.
# Skipping index 465: No bounding boxes found.
# Skipping index 467: No bounding boxes found.
# Skipping index 468: No bounding boxes found.
# Skipping index 469: No bounding boxes found.
# Skipping index 473: No bounding boxes found.
# Skipping index 477: No bounding boxes found.
# Skipping index 483: No bounding boxes found.
# Skipping index 484: No bounding boxes found.
# Skipping index 485: No bounding boxes found.
# Skipping index 490: No bounding boxes found.
# Skipping index 496: No bounding boxes found.
# Skipping index 503: No bounding boxes found.
# Skipping index 506: No bounding boxes found.
# Skipping index 510: No bounding boxes found.
# Skipping index 518: No bounding boxes found.
# Skipping index 519: No bounding boxes found.
# Skipping index 525: No bounding boxes found.
# Skipping index 530: No bounding boxes found.
# Skipping index 537: No bounding boxes found.
# Skipping index 538: No bounding boxes found.
# Skipping index 539: No bounding boxes found.
# Skipping index 546: No bounding boxes found.
# Skipping index 550: No bounding boxes found.
# Skipping index 551: No bounding boxes found.
# Skipping index 552: No bounding boxes found.
# Skipping index 558: No bounding boxes found.
# Skipping index 562: No bounding boxes found.
# Skipping index 563: No bounding boxes found.
# Skipping index 564: No bounding boxes found.
# Skipping index 569: No bounding boxes found.
# Skipping index 576: No bounding boxes found.
# Skipping index 579: No bounding boxes found.
# Skipping index 582: No bounding boxes found.
# Skipping index 586: No bounding boxes found.
# Skipping index 592: No bounding boxes found.
# Skipping index 597: No bounding boxes found.
# Train data shape: torch.Size([1873, 1, 128, 128]), Train targets count: 1873
# Validation data shape: torch.Size([447, 1, 128, 128]), Validation targets count: 447

# %%
print(f"Number of training images: {len(x_train)}")
print(f"Number of training targets: {len(y_train)}")
print(f"Number of validation images: {len(x_val)}")
print(f"Number of validation targets: {len(y_val)}")
# Out:
# Number of training images: 1873
# Number of training targets: 1873
# Number of validation images: 447
# Number of validation targets: 447

# %%
from torch.utils.data import Dataset

# def collate_fn(batch):
#     images, targets = zip(*batch)
    
#     # 将图像列表转换为张量，并移动到指定设备
#     images = [img if isinstance(img, torch.Tensor) else torch.tensor(img, dtype=torch.float32) for img in images]
    
#     # 将目标列表中的每个字典的值转换为张量，并移动到指定设备
#     targets = [{k: v if isinstance(v, torch.Tensor) else torch.tensor(v) for k, v in t.items()} for t in targets]
    
#     return images, targets
def collate_fn(batch):
    images, targets = zip(*batch)
    return list(images), list(targets)
class CustomDataset(Dataset):
    def __init__(self, images, targets):
        """
        自定義數據集，用於 Faster R-CNN 的訓練。
        Args:
            images (torch.Tensor): 圖像數據，形狀為 (N, C, H, W)。
            targets (list): 目標數據，每個元素是包含 `boxes` 和 `labels` 的字典。
        """
        self.images = images
        self.targets = targets

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        return self.images[idx], self.targets[idx]

# %%
# 創建 Dataset
dataset_train = CustomDataset(x_train, y_train)
dataset_val = CustomDataset(x_val, y_val)

# 創建 DataLoader
dl_train = DataLoader(dataset_train, batch_size=32, shuffle=True, collate_fn=collate_fn)
dl_val = DataLoader(dataset_val, batch_size=32, shuffle=False, collate_fn=collate_fn)

# %%
from torchmetrics.detection.mean_ap import MeanAveragePrecision
# from torchmetrics.classification import MulticlassAccuracy
class SimpleTrainer:
    def __init__(self, model, optimizer, device="cuda:0"):
        self.model = model.to(device)
        self.optimizer = optimizer
        self.device = device
        self.iou_metric = MeanAveragePrecision(box_format='xyxy', iou_thresholds=[0.5]).to(device)
        # self.classification_metric = MulticlassAccuracy(num_classes=10, average='weighted').to(device)
    
    def train_step(self, dataloader):
        
        train_loss = 0
        # 清空 metrics
        self.iou_metric.reset()
        # self.classification_metric.reset()

        for batch_x, batch_y in dataloader:
            self.model.train()
            batch_x = [img.to(self.device) for img in batch_x]
            batch_y = [{k: v.to(self.device) for k, v in t.items()} for t in batch_y]
            
            # 正向传播计算损失
            losses = self.model(batch_x, batch_y)
            loss_value = sum(loss for loss in losses.values())
            train_loss += loss_value.item()

            # 反向传播和优化
            self.optimizer.zero_grad()
            loss_value.backward()
            self.optimizer.step()

            # 计算分类准确率和 IoU
            with torch.no_grad():
                # print("evaluation!")
                self.model.eval()
                pred_y = self.model(batch_x)
                # for i, pred in enumerate(pred_y):
                #     print(f"Checking pred_y[{i}]")
                #     check_dict_values(pred)
                # print("predict done!")
                
                # print("pred_y: ",pred_y)
                # # print("batch_x",batch_x.shape)
                # # print(f"pred_y type: {type(pred_y)}")
                # print(f"pred_y boxes: {pred_y[0]['boxes'].shape}")
                # print(f"pred_y labels: {pred_y[0]['labels'].shape}")
                # print(f"pred_y score: {pred_y[0]['scores'].shape}")
                # print(f"pred_y boxes: {pred_y[0]['boxes']}")
                # print(f"pred_y labels: {pred_y[0]['labels']}")
                # print(f"pred_y score: {pred_y[0]['scores']}")
                # # print(f"batch_x type: {type(batch_x)}")
                # # print(f"batch_x content: {batch_x}")
                # pred_y = [
                #     {k: v.to(self.device) if isinstance(v, torch.Tensor) else torch.tensor(v).to(self.device) for k, v in t.items()}
                #     for t in pred_y
                # ]
                # print("after!!!!")
                # print(f"pred_y boxes: {pred_y[0]['boxes'].shape}")
                # print(f"pred_y labels: {pred_y[0]['labels'].shape}")
                # print(f"pred_y score: {pred_y[0]['scores'].shape}")
                # print(f"pred_y boxes: {pred_y[0]['boxes']}")
                # print(f"pred_y labels: {pred_y[0]['labels']}")
                # print(f"pred_y score: {pred_y[0]['scores']}")
                self.iou_metric.update(pred_y, batch_y)
                # print("iou_metric done!")
                # pred_labels = torch.cat([p["labels"] for p in pred_y], dim=0)
                # true_labels = torch.cat([t["labels"] for t in batch_y], dim=0)
                # self.classification_metric.update(pred_labels, true_labels)
                # break
                
        
        # 计算平均损失和准确率
        train_loss /= len(dataloader.dataset)
        # classification_accuracy = self.classification_metric.compute()
        iou_accuracy = self.iou_metric.compute()
        
        print(f"train_loss={train_loss:.4f}, mAP={iou_accuracy['map']:.4f}")
        return train_loss, iou_accuracy['map']
    
    def test_step(self, dataloader):
        """
        执行模型的测试评估
        """
        self.model.eval()
        test_loss = 0

        # 清空 metrics
        self.iou_metric.reset()
        # self.classification_metric.reset()
        print('test start')
        with torch.no_grad():
            for batch_x, batch_y in dataloader:
                batch_x = [img.to(self.device) for img in batch_x]
                batch_y = [{k: v.to(self.device) for k, v in t.items()} for t in batch_y]

                # 预测结果
                predictions = self.model(batch_x)
                
                # 计算损失（如果需要测试阶段的损失值）
                if len(batch_y) > 0:
                    losses = self.model(batch_x, batch_y)
                    loss_value = sum(loss for loss in losses.values())
                    test_loss += loss_value.item()

                # 更新 metrics
                self.iou_metric.update(predictions, batch_y)
                # pred_labels = torch.cat([p["labels"] for p in predictions], dim=0)
                # true_labels = torch.cat([t["labels"] for t in batch_y], dim=0)
                # self.classification_metric.update(pred_labels, true_labels)

        # 计算平均测试损失
        test_loss /= len(dataloader.dataset)

        # 计算准确率
        # classification_accuracy = self.classification_metric.compute()
        iou_accuracy = self.iou_metric.compute()

        print(f"test_loss={test_loss:.4f}, mAP={iou_accuracy['map']:.4f}")
        return test_loss, iou_accuracy['map']
    
    def fit(self, dl_train, dl_test, num_epochs):
        self.metrics = {
            "train_loss": [],
            "test_loss": [],
            "train_classification_acc": [],
            "test_classification_acc": [],
            "train_map": [],
            "test_map": []
        }
        for epoch in range(num_epochs):
            print(f"Epoch {epoch+1}/{num_epochs}")
            train_loss, train_map  = self.train_step(dl_train)
            # print('train done!')
            test_loss, test_map = self.test_step(dl_test)
            self.metrics["train_loss"].append(train_loss)
            self.metrics["test_loss"].append(test_loss)
            # self.metrics["train_classification_acc"].append(train_classification_acc)
            # self.metrics["test_classification_acc"].append(test_classification_acc)
            self.metrics["train_map"].append(train_map)
            self.metrics["test_map"].append(test_map)
        
    def graph_map(self):
        import matplotlib.pyplot as plt
        plt.plot(self.metrics["train_map"], label="train_map")
        plt.plot(self.metrics["test_map"], label="test_map")
        plt.legend()
        plt.show()
        
    # def graph_class_acc(self):
    #     import matplotlib.pyplot as plt
    #     plt.plot(self.metrics["train_classification_acc"], label="train_classification_acc")
    #     plt.plot(self.metrics["test_classification_acc"], label="test_classification_acc")
    #     plt.legend()
    #     plt.show()
        
    def graph_loss(self):
        import matplotlib.pyplot as plt
        plt.plot(self.metrics["train_loss"], label="train_loss")
        plt.plot(self.metrics["test_loss"], label="test_loss")
        plt.legend()
        plt.show()

# %%
print(f"Number of training images: {len(x_train)}")
len(dl_train.dataset)
# Out:
# Number of training images: 1873
# 1873

# %%
from torchvision.models.detection import fasterrcnn_resnet50_fpn
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

# 初始化 Faster R-CNN 模型
model = fasterrcnn_resnet50_fpn(pretrained=True)
model.eval()

# 獲取原始分類頭的輸入特徵數量
num_classes = 10  # 包括背景類別
in_features = model.roi_heads.box_predictor.cls_score.in_features

# 替換為新的分類頭
model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)
model = model.to("cuda:0")
# 測試 DataLoader
for images, targets in dl_train:
    # 將圖像移動到 GPU
    img = [image.to("cuda:0") for image in images]
    
    # 模型推理
    with torch.no_grad():  # 禁用梯度計算
        predictions = model(img)
    
    # 打印結果（僅供測試）
    print(predictions)

    # 清除變數，釋放 CUDA 記憶體
    del img, predictions
    torch.cuda.empty_cache()  # 釋放未使用的記憶體
    break

# %%
from torchvision.models.detection import fasterrcnn_resnet50_fpn
from torch.optim import Adam
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
# 初始化优化器

# 初始化 Faster R-CNN 模型
frcnn_model = fasterrcnn_resnet50_fpn(pretrained=True)

num_classes = 10  # 包括背景類別
in_features = frcnn_model.roi_heads.box_predictor.cls_score.in_features

# 替換為新的分類頭
frcnn_model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)
frcnn_model = frcnn_model.to("cuda:0")
num_epochs = 50
learning_rate = 1e-4
optimizer = Adam(frcnn_model.parameters(), lr=learning_rate)
model = SimpleTrainer(frcnn_model, optimizer)
metric = model.fit(dl_train, dl_val,num_epochs)
# # 測試 DataLoader
# # for images, targets in dl_train:
# #     # 前向傳播
# #     loss = model(images, targets)
# #     loss_value = sum(sep_loss for sep_loss in loss.values())
# #     print(loss_value)
# #     break
# Out:
# c:\Users\Nico\anaconda3\envs\dev310-mldl\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\Nico\anaconda3\envs\dev310-mldl\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=FasterRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1/50

# %%
import torch

if torch.cuda.is_available():
    print("CUDA is available!")
    print("GPU Device:", torch.cuda.get_device_name(0))
else:
    print("CUDA is not available. Using CPU only.")
# Out:
# CUDA is available!
# GPU Device: NVIDIA GeForce GTX 1080
